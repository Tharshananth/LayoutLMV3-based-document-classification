# %%
from transformers import LayoutLMv3FeatureExtractor, LayoutLMv3TokenizerFast, LayoutLMv3Processor, LayoutLMv3ForSequenceClassification
from tqdm import tqdm
import json
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from PIL import Image, ImageDraw, ImageFont
import numpy as np
from sklearn.model_selection import train_test_split
import imgkit
import easyocr
import torchvision.transforms as T
from pathlib import Path
import matplotlib.pyplot as plt
import os
import cv2
from typing import List
import json
from torchmetrics import Accuracy
from huggingface_hub import notebook_login
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.1.1+cu121
# True

# %%
# %matplotlib inline
pl.seed_everything(42)
# Out:
# Seed set to 42
# 42

# %%
image_dir=Path(r"C:\Users\tharshananth N\appian ai\fintech")

# %%
for dir in image_dir.glob("*"):
       class_dir_img=image_dir /dir.name 
       class_dir_img.mkdir(exist_ok=True, parents=True)

# %%
dir
# Out:
# WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility')

# %%
class_dir=list(image_dir.glob("*"))
class_dir
# Out:
# [WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility')]

# %%
image_paths = sorted([p for p in image_dir.glob("*/*.jpg") if p.is_file()])
image_paths
# Out:
# [WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/11.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/17.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/23.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/3.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/31.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/34.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/37.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/39.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/41.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/42.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/44.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/45.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/46.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/47.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/49.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/5.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/51.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/52.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/53.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/54.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/55.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/56.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/57.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/58.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/59.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/6.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/60.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/61.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/62.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/63.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/64.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/65.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/66.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/67.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/68.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/69.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/7.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/70.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/71.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/72.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/73.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/74.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/75.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/76.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/77.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/78.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/79.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/8.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/80.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/81.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/82.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/83.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/84.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/85.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/86.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/88.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/89.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/90.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/91.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/92.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/93.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/94.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/95.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/96.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/97.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/98.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/100.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/11.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/17.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/23.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/3.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/31.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/34.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/36.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/37.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/38.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/39.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/4.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/40.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/41.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/42.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/44.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/45.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/46.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/47.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/48.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/49.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/5.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/50.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/51.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/52.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/53.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/54.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/55.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/56.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/57.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/58.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/59.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/6.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/60.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/61.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/62.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/63.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/64.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/65.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/66.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/67.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/68.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/69.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/7.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/71.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/72.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/73.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/74.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/75.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/76.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/77.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/78.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/79.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/8.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/80.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/81.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/82.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/83.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/84.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/85.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/86.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/87.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/88.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/89.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/9.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/90.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/91.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/92.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/93.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/94.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/95.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/96.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/97.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/98.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Check/99.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/100.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/101.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/11.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/17.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/23.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/3.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/31.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/36.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/38.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/4.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/40.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/41.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/ITR_Form 16/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/100.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/101.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/102.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/11.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/31.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/34.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/36.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/37.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/38.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/39.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/4.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/40.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/42.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/44.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/45.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/47.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/48.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/49.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/5.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/50.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/51.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/52.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/53.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/54.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/55.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/57.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/58.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/59.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/60.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/61.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/62.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/63.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/64.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/65.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/66.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/67.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/68.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/69.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/7.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/70.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/71.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/72.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/73.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/74.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/75.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/76.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/77.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/78.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/79.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/8.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/80.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/81.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/82.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/83.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/84.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/85.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/86.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/87.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/88.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/89.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/9.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/90.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/91.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/92.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/93.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/95.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/96.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/97.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/98.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Salary Slip/99.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/100.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/17.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/23.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/3.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/34.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/36.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/37.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/38.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/39.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/4.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/40.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/41.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/42.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/44.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/45.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/46.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/47.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/48.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/49.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/50.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/51.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/52.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/53.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/54.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/55.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/56.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/57.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/58.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/59.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/6.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/60.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/61.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/62.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/63.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/64.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/65.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/66.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/67.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/68.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/69.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/7.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/70.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/71.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/72.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/73.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/74.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/75.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/76.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/77.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/78.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/79.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/8.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/80.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/81.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/83.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/84.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/85.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/86.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/87.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/88.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/89.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/9.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/90.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/91.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/92.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/93.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/94.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/95.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/96.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/97.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/98.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Utility/99.jpg')]

# %%
if image_paths:
       try:
              image=Image.open(image_paths[0]).convert('RGB')
              width, height=image.size
              print(f'width:{width}X height:{height}')
              
              plt.imshow(image)
              plt.axis('off')
              plt.show()
       except Exception as e:
            print(f"Error opening image: {e}")
      
else:
       print('no ')
# Out:
# width:768X height:1024

# %%
from easyocr import Reader

ini = str(image_paths[0])

reader = Reader(['en'])

ocr_result = reader.readtext(ini)
for bbox, text, confidence in ocr_result:
    print(f"Detected text: {text}, Confidence: {confidence}")
# Out:
# Detected text: AXIS BANK, Confidence: 0.8319232761526623
# Detected text: STATEMENT BETWEEN, Confidence: 0.9361189517805588
# Detected text: 01/04/2019 AND, Confidence: 0.8127516397534338
# Detected text: 30/04/2019 FOR AIC: 918020087855304, Confidence: 0.8613523183586869
# Detected text: 589, Confidence: 0.9999821053874435
# Detected text: INNOVACION AIR CONDITIONING, Confidence: 0.7370530296358013
# Detected text: SCHEME CODE, Confidence: 0.9452615824745251
# Detected text: CA- LAAGE ReTAILeRS AND, Confidence: 0.36911374088783994
# Detected text: DISTR IBUTORS, Confidence: 0.6505274132768822
# Detected text: KARo 27/3 [, Confidence: 0.12105104293729542
# Detected text: UDAY VIHAR, Confidence: 0.8133352342979157
# Detected text: customeR ID, Confidence: 0.28096742326033863
# Detected text: 885841520, Confidence: 0.8044487824660068
# Detected text: NILOTHI EXTN_ WEST DELHI DELHI, Confidence: 0.4635272919096972
# Detected text: CURRENCY CODE, Confidence: 0.975501066532019
# Detected text: POOJA DAIRY, Confidence: 0.8604755568349667
# Detected text: VEN AMOUNT, Confidence: 0.696326039634878
# Detected text: Donon, Confidence: 0.00952573845777507
# Detected text: AMUB NIBRYa, Confidence: 0.045940677942848236
# Detected text: Leman, Confidence: 0.02279434374796635
# Detected text: Mcnnneree, Confidence: 8.976284407886289e-05
# Detected text: T=, Confidence: 0.039736088988200594
# Detected text: TILKNAGAR, Confidence: 0.38643007535982415
# Detected text: 250201g, Confidence: 0.24793860225634778
# Detected text: 2J Wl Zut, Confidence: 0.16116499482117316
# Detected text: "Gs ICICHIYTISJUNCDSULLKIMOTC, Confidence: 0.0066530979002191685
# Detected text: obz uui, Confidence: 0.02397598057320464
# Detected text: 36388, Confidence: 0.2890955639381181
# Detected text: BANGA [PBI, Confidence: 0.28590484815188716
# Detected text: 0 042019, Confidence: 0.6060681805174909
# Detected text: 30753052/chott, Confidence: 0.29491177621383136
# Detected text: 4511, Confidence: 0.30267688632011414
# Detected text: Ce, Confidence: 0.002362512730602397
# Detected text: Vunae, Confidence: 0.1401453708946607
# Detected text: 042019, Confidence: 0.8070356848045345
# Detected text: gutoudoliGurmee, Confidence: 0.1289372516272288
# Detected text: suujuui, Confidence: 0.13058372365287366
# Detected text: 3937>, Confidence: 0.060361026563063226
# Detected text: BHATANIPAMS, Confidence: 0.13841180919891405
# Detected text: 04201g, Confidence: 0.2696804062291308
# Detected text: 29 0A, Confidence: 0.09129386389159683
# Detected text: OP/SF, Confidence: 0.14523332883403978
# Detected text: 3010 6, Confidence: 0.621722561154757
# Detected text: O0oolo 0, Confidence: 0.12300135015050842
# Detected text: TILAKMAGAR, Confidence: 0.6651417600382846
# Detected text: Kotorizono, Confidence: 0.007238210866913113
# Detected text: 5loVol2ut, Confidence: 0.015261367686724262
# Detected text: AECTS 4u7SIB WieespiRiDEIKIHMOT, Confidence: 0.000995656393330319
# Detected text: Toldloto 6, Confidence: 0.05493420578428709
# Detected text: Teninatan, Confidence: 0.010233991337645947
# Detected text: TIDIKNAGAR, Confidence: 0.19510259911837508
# Detected text: 70 042019, Confidence: 0.35643045181868144
# Detected text: 20,m20to, Confidence: 0.08833682748053041
# Detected text: Nps P2a 01201577335414521144268462, Confidence: 0.020989950479731
# Detected text: 5005, Confidence: 0.7425330281257629
# Detected text: 14575801, Confidence: 0.12342649334056004
# Detected text: TDKNAGHR, Confidence: 0.1987442765356919
# Detected text: TRANSACTION TOTAL DRICR:, Confidence: 0.8563480550925202
# Detected text: 304647.00, Confidence: 0.66381695718311
# Detected text: CLOSING BALANCE, Confidence: 0.9994837501239227
# Detected text: 372700.00, Confidence: 0.6422070844128314
# Detected text: 115368.01, Confidence: 0.605263797021379
# Detected text: Page, Confidence: 0.9999509453773499
# Detected text: ot 2, Confidence: 0.5481651415420268
# Detected text: Crinde, Confidence: 0.14283883573350223

# %%
def create_bounding_box(bbox_data):
    xs = []
    ys = []
    for x, y in bbox_data:
        xs.append(x)
        ys.append(y)
 
    left = int(min(xs))
    top = int(min(ys))
    right = int(max(xs))
    bottom = int(max(ys))
 
    return [left, top, right, bottom]
 
font_path = Path(cv2.__path__[0]) / r"C:\Users\tharshananth N\Downloads\DejaVuSansCondensed.ttf"
font = ImageFont.truetype(str(font_path), size=12)
 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(28, 28))
 
left_image = Image.open(ini).convert("RGB")
right_image = Image.new("RGB", left_image.size, (255, 255, 255))
 
left_draw = ImageDraw.Draw(left_image)
right_draw = ImageDraw.Draw(right_image)
 
for i, (bbox, word, confidence) in enumerate(ocr_result):
    box = create_bounding_box(bbox)
 
    left_draw.rectangle(box, outline="blue", width=2)
    left, top, right, bottom = box
 
    left_draw.text((right + 5, top), text=str(i + 1), fill="red", font=font)
    right_draw.text((left, top), text=word, fill="black", font=font)
 
ax1.imshow(left_image)
ax2.imshow(right_image)
ax1.axis("off");
ax2.axis("off");

# %%
import cv2
import json
from tqdm import tqdm
from pathlib import Path
import os
import numpy as np  

from easyocr import Reader
reader = Reader(['en'], gpu=True)  

image_paths =  [
    file for file in Path(r"C:\Users\tharshananth N\appian ai\fintech").rglob("*")
    if file.suffix.lower() in {'.png', '.jpg', '.jpeg'}
]
ocr_results = {}

for ini in tqdm(image_paths, desc="Processing Images"):
    try:
        img = cv2.imread(str(ini))
        if img is None:
            print(f"Skipping invalid image: {ini}")
            continue

        ocr_result = reader.readtext(img, batch_size=4)

        ocr_page = []
        for bbox, word, confidence in ocr_result:
            bbox = [list(map(int, coord)) for coord in bbox]  
            ocr_page.append({
                "bbox": bbox,
                "word": word,
                "confidence": float(confidence)  
            })

        ocr_results[str(ini)] = ocr_page

    except Exception as e:
        print(f"Error processing image {ini}: {e}")
# Out:
# Processing Images: 100%|██████████| 415/415 [12:59<00:00,  1.88s/it]

# %%
with open("ocr_results.json") as json_file:
      ocr_results = json.load(json_file)

# %%
output_file = Path(r"C:\Users\tharshananth N\appian ai\ocr_results.json")

with open(output_file, "w") as json_file:
    json.dump(ocr_results, json_file, indent=4)

print(f"OCR results saved to {output_file}")
# Out:
# OCR results saved to C:\Users\tharshananth N\appian ai\ocr_results.json

# %%
output_file = Path(r"C:\Users\tharshananth N\appian ai\ocr_results.json")

with open(output_file, "w") as json_file:
    json.dump(ocr_results, json_file, indent=4)

print(f"OCR results saved to {output_file}")
# Out:
# OCR results saved to C:\Users\tharshananth N\appian ai\ocr_results.json

# %%
image_paths = [
    file for file in Path(r"C:\Users\tharshananth N\appian ai\fintech").rglob("*")
    if file.suffix.lower() in {'.png', '.jpg', '.jpeg'}
]
image_paths
# Out:
# [WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/1.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/10.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/11.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/12.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/13.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/14.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/15.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/16.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/17.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/18.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/19.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/2.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/20.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/21.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/22.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/23.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/24.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/25.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/26.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/27.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/28.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/29.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/3.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/30.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/31.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/32.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/33.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/34.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/35.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/37.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/39.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/41.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/42.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/43.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/44.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/45.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/46.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/47.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/49.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/5.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/51.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/52.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/53.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/54.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/55.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/56.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/57.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/58.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/59.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/6.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/60.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/61.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/62.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/63.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/64.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/65.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/66.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/67.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/68.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/69.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/7.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/70.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/71.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/72.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/73.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/74.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/75.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/76.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/77.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/78.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/79.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/8.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/80.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement/81.jpg'),
#  WindowsPath('C:/Users/tharshananth N/appian ai/fintech/Bank Statement
atureExtractor is deprecated and will be removed in version 5 of Transformers. Please use LayoutLMv3ImageProcessor instead.
#   warnings.warn(
# c:\Users\tharshananth N\.conda\envs\fast_gpu\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
ini = image_paths[0]
image = Image.open(ini).convert("RGB")
width, height = image.size
 
width_scale = 1000 / width
height_scale = 1000 / height

# %%
from pathlib import Path
import json
from typing import List

def scale_bounding_box(box: List[int], width_scale: float = 1.0, height_scale: float = 1.0) -> List[int]:
    """Scales a bounding box by the given width and height factors.

    Args:
        box: A list containing four integers representing the top-left and bottom-right coordinates of the bounding box (e.g., [x1, y1, x2, y2]).
        width_scale: The factor by which to scale the width of the bounding box (default: 1.0).
        height_scale: The factor by which to scale the height of the bounding box (default: 1.0).

    Returns:
        A new list containing the scaled bounding box coordinates.

    Raises:
        ValueError: If the `box` argument is not a list of four elements.
        TypeError: If the elements in the `box` list cannot be multiplied by the scale factors.
    """
    if not isinstance(box, list) or len(box) != 4:
        raise ValueError("Invalid box format. Expected a list of four integers.")

    try:
        return [int(round(x * scale)) for x, scale in zip(box, [width_scale, height_scale, width_scale, height_scale])]
    except TypeError:
        raise TypeError("Invalid data type in box. Expected integers.")

def convert_polygon_to_bbox(polygon: List[List[int]]) -> List[int]:
    """Converts a four-point polygon to a bounding box in [x1, y1, x2, y2] format.

    Args:
        polygon: A list of four points, each represented as [x, y].

    Returns:
        A list containing the bounding box in [x1, y1, x2, y2] format.

    Raises:
        ValueError: If the polygon does not have exactly four points.
    """
    if len(polygon) != 4:
        raise ValueError("Polygon must have exactly four points.")
    
    x_coords = [point[0] for point in polygon]
    y_coords = [point[1] for point in polygon]
    return [min(x_coords), min(y_coords), max(x_coords), max(y_coords)]

def process_ocr_results(json_path: Path, width_scale: float = 1.0, height_scale: float = 1.0):
    """Processes OCR results, scales bounding boxes, and collects words.

    Args:
        json_path: Path to the OCR results JSON file.
        width_scale: Scaling factor for bounding box width.
        height_scale: Scaling factor for bounding box height.
    """
    with json_path.open("r") as f:
        ocr_result = json.load(f)

    words = []
    boxes = []

    for image_path, word_data_list in ocr_result.items():
        for word_data in word_data_list:
            try:
                if isinstance(word_data, dict):
                    bbox = word_data["bbox"]
                    if isinstance(bbox[0], list) and len(bbox) == 4:
                        bbox = convert_polygon_to_bbox(bbox)

                    if not (isinstance(bbox, list) and len(bbox) == 4 and all(isinstance(coord, (int, float)) for coord in bbox)):
                        print(f"Invalid bbox format: {bbox}")
                        continue

                    scaled_box = scale_bounding_box([int(round(float(x))) for x in bbox], width_scale, height_scale)
                    boxes.append(scaled_box)
                    words.append(word_data["word"])
                else:
                    print(f"Warning: Unexpected data type for word_data in {image_path}: {type(word_data)}")
            except Exception as e:
                print(f"Error processing {image_path}: {e}")

    return words, boxes

if __name__ == "__main__":
    json_path = Path(r"C:\Users\tharshananth N\appian ai\ocr_results.json")
    words, boxes = process_ocr_results(json_path, width_scale=1.0, height_scale=1.0)
    print(f"Number of words: {len(words)}")
    print(f"Number of bounding boxes: {len(boxes)}")
# Out:
# Number of words: 28042
# Number of bounding boxes: 28042

# %%
from transformers import LayoutLMv3Processor

# %%
processor = LayoutLMv3Processor.from_pretrained("microsoft/layoutlmv3-base")
# Out:
# c:\Users\tharshananth N\.conda\envs\fast_gpu\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\tharshananth N\.conda\envs\fast_gpu\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\tharshananth N\.cache\huggingface\hub\models--microsoft--layoutlmv3-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
encoding = processor(
    image,
    words,
    boxes=boxes,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)
 
print(f"""
input_ids:  {list(encoding["input_ids"].squeeze().shape)}
word boxes: {list(encoding["bbox"].squeeze().shape)}
image data: {list(encoding["pixel_values"].squeeze().shape)}
image size: {image.size}
""")
# Out:
# input_ids:  [512]
# word boxes: [512, 4]
# image data: [3, 224, 224]
# image size: (768, 1024)

# %%
image_data = encoding["pixel_values"][0]
transform = T.ToPILImage()
transform(image_data)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
model = LayoutLMv3ForSequenceClassification.from_pretrained(
    "microsoft/layoutlmv3-base", num_labels=2
)
# Out:
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_images, test_images = train_test_split(image_paths, test_size=0.2, random_state=42)

DOCUMENT_CLASSES = sorted(list(map(
    lambda p: p.name,
    image_dir.glob("*")  # Top-level folders represent classes
)))

print("Document Classes:", DOCUMENT_CLASSES)
print("Number of Training Images:", len(train_images))
print("Number of Testing Images:", len(test_images))
# Out:
# Document Classes: ['Bank Statement', 'Check', 'ITR_Form 16', 'Salary Slip', 'Utility']
# Number of Training Images: 332
# Number of Testing Images: 83

# %%
class DocumentClassificationDataset(Dataset):
 
    def __init__(self, image_paths, processor):
        self.image_paths = image_paths
        self.processor = processor
 
    def __len__(self):
        return len(self.image_paths)
 
    def __getitem__(self, item):
 
        image_path = self.image_paths[item]
        json_path = image_path.with_suffix(".json")
        with json_path.open("r") as f:
            ocr_result = json.load(f)
 
            with Image.open(image_path).convert("RGB") as image:
 
                width, height = image.size
                width_scale = 1000 / width
                height_scale = 1000 / height
 
                words = []
                boxes = []
                for row in ocr_result:
                    boxes.append(scale_bounding_box(
                        row["bounding_box"],
                        width_scale,
                        height_scale
                    ))
                    words.append(row["word"])
 
                encoding = self.processor(
                    image,
                    words,
                    boxes=boxes,
                    max_length=512,
                    padding="max_length",
                    truncation=True,
                    return_tensors="pt"
                )
 
        label = DOCUMENT_CLASSES.index(image_path.parent.name)
 
        return dict(
            input_ids=encoding["input_ids"].flatten(),
            attention_mask=encoding["attention_mask"].flatten(),
            bbox=encoding["bbox"].flatten(end_dim=1),
            pixel_values=encoding["pixel_values"].flatten(end_dim=1),
            labels=torch.tensor(label, dtype=torch.long)
        )

# %%
train_dataset = DocumentClassificationDataset(train_images, processor)
test_dataset = DocumentClassificationDataset(test_images, processor)
 
train_data_loader = DataLoader(
    train_dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2
)
 
test_data_loader = DataLoader(
    test_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=2
)

# %%
class ModelModule(pl.LightningModule):
    def __init__(self, n_classes:int):
        super().__init__()
        self.model = LayoutLMv3ForSequenceClassification.from_pretrained(
            "microsoft/layoutlmv3-base",
            num_labels=n_classes
        )
        self.model.config.id2label = {k: v for k, v in enumerate(DOCUMENT_CLASSES)}
        self.model.config.label2id = {v: k for k, v in enumerate(DOCUMENT_CLASSES)}
        self.train_accuracy = Accuracy(task="multiclass", num_classes=n_classes)
        self.val_accuracy = Accuracy(task="multiclass", num_classes=n_classes)
 
    def forward(self, input_ids, attention_mask, bbox, pixel_values, labels=None):
        return self.model(
            input_ids,
            attention_mask=attention_mask,
            bbox=bbox,
            pixel_values=pixel_values,
            labels=labels
        )
 
    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        bbox = batch["bbox"]
        pixel_values = batch["pixel_values"]
        labels = batch["labels"]
        output = self(input_ids, attention_mask, bbox, pixel_values, labels)
        self.log("train_loss", output.loss)
        self.log(
            "train_acc",
            self.train_accuracy(output.logits, labels),
            on_step=True,
            on_epoch=True
        )
        return output.loss
 
    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        bbox = batch["bbox"]
        pixel_values = batch["pixel_values"]
        labels = batch["labels"]
        output = self(input_ids, attention_mask, bbox, pixel_values, labels)
        self.log("val_loss", output.loss)
        self.log(
            "val_acc",
            self.val_accuracy(output.logits, labels),
            on_step=False,
            on_epoch=True
        )
        return output.loss
 
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.model.parameters(), lr=0.00001) #1e-5
        return optimizer

# %%
model_module = ModelModule(len(DOCUMENT_CLASSES))
# Out:
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
torch.set_float32_matmul_precision("medium")

# %%
model_checkpoint = ModelCheckpoint(
    filename="{epoch}-{step}-{val_loss:.4f}", save_last=True, save_top_k=3, monitor="val_loss", mode="min"
)
 
trainer = pl.Trainer(
    accelerator="gpu",
    precision=16,
    devices=1,
    max_epochs=5,
    callbacks=[
        model_checkpoint
    ],
)
# Out:
# c:\Users\tharshananth N\.conda\envs\fast_gpu\lib\site-packages\lightning_fabric\connector.py:572: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model_module, train_data_loader, test_data_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name           | Type                                | Params | Mode
# -------------------------------------------------------------------------------
# 0 | model          | LayoutLMv3ForSequenceClassification | 125 M  | eval
# 1 | train_accuracy | MulticlassAccuracy                  | 0      | train
# 2 | val_accuracy   | MulticlassAccuracy                  | 0      | train
# -------------------------------------------------------------------------------
# 125 M     Trainable params
# 0         Non-trainable params
# 125 M     Total params
# 503.686   Total estimated model params size (MB)
# 2         Modules in train mode
# 243       Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\tharshananth N\.conda\envs\fast_gpu\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
